# %%
import numpy as np
import pandas

# %%
path = './data.csv'

# %%
#Helper functions

def reading(path):
    
    df = pandas.read_csv(path)
    #take the first row and put as columns header in df
    header = df.iloc[0]
    df = df[1: ]
    df.columns =header
    df = data.set_index('Processes')

    df.head()

    return df

# %%
data = reading(path)
data.head()
# Out:
# 0         M-001 M-002 M-003 M-004 M-005 M-006 M-007 M-008 M-009 M-010  ...  \
# Processes                                                              ...
# P-001       -73     0    59     0    48     0     0     0     0     0  ...
# P-002         0     0     0     0    73     0     0    11     0    69  ...
# P-003         0     0     0    58    26     0     0    92    43     0  ...
# P-004         0    71   -28     0   -76     0     4   -12     0     0  ...
# P-005         0    -2     0   -71    37     0     0    19    16   -43  ...
#
# 0         M-012 M-013 M-014 M-015 M-016 M-017 M-018 M-019 M-020 Cost/Energy…?
# Processes
# P-001       -60     0     0   -26     0     0    -9   -15     0             ?
# P-002         0    36   -33    33   -82    64     0   -38   -92             ?
# P-003       -42    34    -4     5     0     0     0     0     0             ?
# P-004         0   -21     0     0   -28     0    18     0     0             ?
# ...
